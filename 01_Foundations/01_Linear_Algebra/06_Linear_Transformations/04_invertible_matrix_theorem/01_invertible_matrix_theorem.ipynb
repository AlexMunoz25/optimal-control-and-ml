# %% [markdown]
# ### 1.1.6.4. Invertible Matrix Theorem

# %% [markdown]
# $$
# A \text{ is invertible} \;\Leftrightarrow\; \mathcal{N}(A) = \{\vec{0}\} \;\Leftrightarrow\; \operatorname{rank}(A) = n \;\Leftrightarrow\; \det(A) \neq 0 \;\Leftrightarrow\; \operatorname{rref}(A) = \mathbb{1}_n
# $$

# %% [markdown]
# **Explanation:**
#
# The invertible matrix theorem connects systems of linear equations, matrices, vector spaces, and linear transformations into one unified statement. For an $n \times n$ matrix $A$, 10 statements are all equivalent — they are either all true or all false.
#
# The set of $n \times n$ matrices splits into two disjoint subsets: invertible matrices (all 10 statements true) and non-invertible matrices (all 10 statements false).
#
# **Example:**
#
# $A = \begin{bmatrix} 2 & 1 \\ 1 & 1 \end{bmatrix}$: $\det(A) = 1 \neq 0$, $\operatorname{rank}(A) = 2 = n$, $\mathcal{N}(A) = \{\vec{0}\}$ — all 10 statements are TRUE.

# %%
import numpy as np

matrix_a = np.array([[2, 1], [1, 1]])
print(f"A =\n{matrix_a}")
print(f"det(A) = {np.linalg.det(matrix_a):.4f}")
print(f"rank(A) = {np.linalg.matrix_rank(matrix_a)}")
print(f"A⁻¹ =\n{np.linalg.inv(matrix_a)}")

# %% [markdown]
# **References:**
#
# [📘 Savov, I. (2016). *No Bullshit Guide to Linear Algebra*, Section 6.4 "Invertible Matrix Theorem."](https://minireference.com/static/excerpts/noBSLA_v2_preview.pdf)
#
# ---
#
# [⬅️ Previous: Similarity Transformation](../03_change_of_basis_for_matrices/04_similarity_transformation.ipynb) | [Next: The 10 Equivalent Statements ➡️](./02_the_10_equivalent_statements.ipynb)
