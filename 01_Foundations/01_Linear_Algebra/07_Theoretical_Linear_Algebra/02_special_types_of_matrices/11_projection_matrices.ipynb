# %% [markdown]
# ### 1.1.7.2.11. Projection Matrices

# %% [markdown]
# $$
# \Pi = \Pi^2 = \Pi^3 = \cdots, \quad \lambda \in \{0, 1\}
# $$

# %% [markdown]
# **Explanation:**
#
# The defining property of a projection matrix is idempotency: $\Pi^2 = \Pi$. A projection has two eigenvalues: $\lambda = 1$ for the invariant subspace $S$ (vectors that remain unchanged) and $\lambda = 0$ for the null space $S^\perp$ (vectors that are annihilated by the projection).
#
# **Example:**
#
# Projection onto the $x$-axis:
#
# $$
# \Pi_x = \begin{bmatrix} 1 & 0 \\ 0 & 0 \end{bmatrix}
# $$
#
# Verify idempotency:
#
# $$
# \Pi_x^2 = \begin{bmatrix} 1 & 0 \\ 0 & 0 \end{bmatrix} \begin{bmatrix} 1 & 0 \\ 0 & 0 \end{bmatrix} = \begin{bmatrix} 1 & 0 \\ 0 & 0 \end{bmatrix} = \Pi_x
# $$
#
# Eigenvalues: $\lambda_1 = 1$, $\lambda_2 = 0$.

# %%
import sympy as sp

direction = sp.Matrix([1, 2])
unit_direction = direction / direction.norm()
projection_matrix = unit_direction * unit_direction.T

print("Projection matrix (onto direction [1, 2]):")
sp.pprint(projection_matrix)

projection_squared = projection_matrix ** 2
print("\nPi^2 =")
sp.pprint(projection_squared)
print("Pi^2 == Pi:", sp.simplify(projection_squared - projection_matrix) == sp.zeros(2, 2))

eigenvalues = list(projection_matrix.eigenvals().keys())
print("\nEigenvalues:", eigenvalues)
# Out:
# Projection matrix (onto direction [1, 2]):
# [[0.2 0.4]
#  [0.4 0.8]]
#
# Pi^2 =
# [[0.2 0.4]
#  [0.4 0.8]]
# Pi^2 == Pi: True
#
# Eigenvalues: [0. 1.]

# %% [markdown]
# **References:**
#
# [📘 Savov, I. (2016). *No Bullshit Guide to Linear Algebra*, Section 7.2](https://minireference.com/)
#
# ---
#
# [⬅️ Previous: Positive Matrices](./10_positive_matrices.ipynb) | [Next: Normal Matrices ➡️](./12_normal_matrices.ipynb)
