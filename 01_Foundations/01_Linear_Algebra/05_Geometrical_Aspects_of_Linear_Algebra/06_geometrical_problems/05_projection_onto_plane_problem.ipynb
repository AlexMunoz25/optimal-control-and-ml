# %% [markdown]
# ### 1.1.5.6.5. Projection onto Plane Problem

# %% [markdown]
# $$
# \Pi_P(\vec{v}) = \vec{v} - \frac{\vec{v} \cdot \vec{n}}{\|\vec{n}\|^2}\,\vec{n}
# $$

# %% [markdown]
# **Explanation:**
#
# Projecting a vector onto a plane through the origin with normal $\vec{n}$ removes the component along $\vec{n}$. This combines the projection formula from Section 5.2 with a concrete geometrical application.
#
# **Example:**
#
# Project $\vec{v} = (3, 4, 1)$ onto the plane with normal $\vec{n} = (2, -1, 4)$:
#
# $$
# \Pi_P(\vec{v}) = (3,4,1) - \frac{6}{21}(2,-1,4) = \left(\frac{19}{7},\; \frac{30}{7},\; -\frac{1}{7}\right)
# $$

# %%
import sympy as sp

vector = sp.Matrix([3, 4, 1])
normal = sp.Matrix([2, -1, 4])

projection_onto_plane = vector - (vector.dot(normal) / normal.dot(normal)) * normal

print(f"v = {list(vector)}")
print(f"n = {list(normal)}")
print(f"Proj_P(v) = {list(projection_onto_plane)}")
print(f"Orthogonality check (dot with n = 0): {projection_onto_plane.dot(normal)}")
# Out:
# v = [3. 4. 1.]
# n = [ 2. -1.  4.]
# Π_P(v) = [ 2.42857143  4.28571429 -0.14285714]
# As fractions: (2.7143, 4.2857, -0.1429)
# Orthogonality check (dot with n = 0): 0.0

# %% [markdown]
# **References:**
#
# [📘 Savov, I. (2016). *No Bullshit Guide to Linear Algebra*, Section 5.6 "Geometrical Problems."](https://minireference.com/static/excerpts/noBSLA_v2_preview.pdf)
#
# ---
#
# [⬅️ Previous: Distance from Point to Plane](./04_distance_point_to_plane.ipynb) | [Next: Linearity ➡️](../../06_Linear_Transformations/01_linear_transformations/01_linearity.ipynb)
