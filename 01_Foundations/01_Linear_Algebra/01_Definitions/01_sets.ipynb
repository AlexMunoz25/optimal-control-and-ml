# %% [markdown]
# ### 1.1.1.1 Sets and Set Notation
#
#
# $$
# \mathbb{N} \subset \mathbb{Z} \subset \mathbb{Q} \subset \mathbb{R} \subset \mathbb{C}
# $$
#
# <div style="display:flex; justify-content:center; align-items:center;">
#   <svg viewBox="0 0 500 200" width="500" height="200"
#        xmlns="http://www.w3.org/2000/svg" style="color:#e6e6e6">
#     <ellipse cx="250" cy="100" rx="230" ry="80" fill="none" stroke="#aaa" stroke-width="1.5"/>
#     <ellipse cx="250" cy="100" rx="180" ry="60" fill="none" stroke="#aaa" stroke-width="1.2"/>
#     <ellipse cx="250" cy="100" rx="130" ry="45" fill="none" stroke="#aaa" stroke-width="1.2"/>
#     <ellipse cx="250" cy="100" rx="80"  ry="30" fill="none" stroke="#aaa" stroke-width="1.2"/>
#     <ellipse cx="250" cy="100" rx="35"  ry="15" fill="none" stroke="#aaa" stroke-width="1.2"/>
#     <text x="255" y="100" text-anchor="middle" dominant-baseline="middle" font-size="20" fill="currentColor">ℕ</text>
#     <text x="305" y="100" text-anchor="middle" dominant-baseline="middle" font-size="20" fill="currentColor">ℤ</text>
#     <text x="352" y="100" text-anchor="middle" dominant-baseline="middle" font-size="20" fill="currentColor">ℚ</text>
#     <text x="400" y="100" text-anchor="middle" dominant-baseline="middle" font-size="20" fill="currentColor">ℝ</text>
#     <text x="450" y="100" text-anchor="middle" dominant-baseline="middle" font-size="20" fill="currentColor">ℂ</text>
#   </svg>
# </div>
#
#
# Mathematicians classify the different kinds of number-like objects into categories called **sets**:
#
# - **The natural numbers:**
#   $\mathbb{N} = \{0, 1, 2, 3, 4, 5, 6, 7, \ldots\}$
#
# - **The integers:**
#   $\mathbb{Z} = \{\ldots, -3, -2, -1, 0, 1, 2, 3, \ldots\}$
#
# - **The rational numbers:**
#   $\mathbb{Q} = \left\{\frac{5}{3}, \frac{22}{7}, 1.5, 0.125, -7, \ldots\right\}$
#
# - **The real numbers:**
#   $\mathbb{R} = \{-1, 0, 1, \sqrt{2}, e, \pi, 4.94\ldots, \ldots\}$
#
# - **The complex numbers:**
#   $\mathbb{C} = \{-1, 0, 1, i, 1+i, 2+3i, \ldots\}$
#
#
# **Definitions:**
#
# - *Set*: a collection of mathematical objects.
# - $S, T$: the usual variable names for sets.
# - $s \in S$: this statement is read “$s$ is an element of $S$” or “$s$ is in $S$.”
# - $\mathbb{N}, \mathbb{Z}, \mathbb{Q}, \mathbb{R}$: important number sets — the naturals, the integers, the rationals, and the reals, respectively.
# - $\varnothing$: the *empty set* is a set that contains no elements.
# - $\{\, \cdot \,\}$: the curly brackets are used to define sets, and the expression inside the curly brackets describes the set contents.
#
#
# **Set operations:**
#
# - $S \cup T$: the *union* of two sets. The union of $S$ and $T$ corresponds to the elements in either $S$ or $T$.
# - $S \cap T$: the *intersection* of the two sets. The intersection of $S$ and $T$ corresponds to the elements that are in both $S$ and $T$.
# - $S \setminus T$: the *set difference* or *set minus*. The set difference $S \setminus T$ corresponds to the elements of $S$ that are not in $T$.
#
#
# **Set relations:**
#
# - $S \subset T$: is a *strict subset* of.
# - $S \subseteq T$: is a *subset of or equal to*.
#
#
# **Example:**
#
# Let
#
# $$
# S = \{1, 2, 3\}, \quad T = \{3, 4\}.
# $$
#
# Then
#
# $$
# S \cup T = \{1, 2, 3, 4\}, \quad S \cap T = \{3\}, \quad S \setminus T = \{1, 2\}.
# $$

# %%
S = {1, 2, 3}
T = {3, 4}

print("S =", S)
print("T =", T)
print("S ∪ T =", S | T)         # Union
print("S ∩ T =", S & T)         # Intersection
print("S \\ T =", S - T)        # Difference (elements in S not in T)
print("T \\ S =", T - S)        # Difference (elements in T not in S)
print("S △ T =", S ^ T)         # Symmetric difference (elements in either S or T, but not both)
print("S ⊂ T =", S < T)         # Strict subset
print("S ⊆ T =", S <= T)        # Subset or equal
print("S ⊃ T =", S > T)         # Strict superset
print("S ⊇ T =", S >= T)        # Superset or equal
print("S ∩ T = ∅:", S.isdisjoint(T))  # Disjoint check
# Out:
# S = {1, 2, 3}
# T = {3, 4}
# S ∪ T = {1, 2, 3, 4}
# S ∩ T = {3}
# S \ T = {1, 2}
# T \ S = {4}
# S △ T = {1, 2, 4}
# S ⊂ T = False
# S ⊆ T = False
# S ⊃ T = False
# S ⊇ T = False
# S ∩ T = ∅: False

# %% [markdown]
# **References:**
#
# [📘 Savov, I. (2014). *No Bullshit Guide to Linear Algebra*](https://minireference.com/static/excerpts/noBSLA_v2_preview.pdf)
#
# ---
#
# [⬅️ Back to Index](../../../../README.md) | [Next: Cartesian Plane ➡️](./02_cartesian_plane.ipynb)
