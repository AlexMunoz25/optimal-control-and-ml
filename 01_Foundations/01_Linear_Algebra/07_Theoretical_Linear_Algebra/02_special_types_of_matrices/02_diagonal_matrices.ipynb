# %% [markdown]
# ### 1.1.7.2.2. Diagonal Matrices

# %% [markdown]
# $$
# A = \begin{bmatrix} a_{11} & 0 & 0 \\ 0 & a_{22} & 0 \\ 0 & 0 & a_{33} \end{bmatrix}, \quad a_{ij} = 0 \;\text{if}\; i \neq j, \quad \lambda_i = a_{ii}
# $$

# %% [markdown]
# **Explanation:**
#
# Diagonal matrices have entries only on the diagonal and zeros everywhere else. The eigenvalues of a diagonal matrix are its diagonal entries. Diagonal matrices are the simplest to work with — powers, exponentials, inverses all reduce to scalar operations on the diagonal.
#
# **Example:**
#
# $$
# D = \text{diag}(2,\, 5,\, -1)
# $$
#
# The eigenvalues are $\lambda_1 = 2$, $\lambda_2 = 5$, $\lambda_3 = -1$. Powers act element-wise on the diagonal:
#
# $$
# D^3 = \text{diag}(2^3,\, 5^3,\, (-1)^3) = \text{diag}(8,\, 125,\, -1)
# $$

# %%
import sympy as sp

diagonal_entries = [2, 5, -1]
diagonal_matrix = sp.diag(*diagonal_entries)

print("D =")
sp.pprint(diagonal_matrix)

eigenvalues = list(diagonal_matrix.eigenvals().keys())
print("\nEigenvalues:", sorted(eigenvalues))

diagonal_cubed = diagonal_matrix ** 3
print("\nD^3 =")
sp.pprint(diagonal_cubed)
# Out:
# D =
# [[ 2  0  0]
#  [ 0  5  0]
#  [ 0  0 -1]]
#
# Eigenvalues: [ 2.  5. -1.]
#
# D^3 =
# [[  8   0   0]
#  [  0 125   0]
#  [  0   0  -1]]

# %% [markdown]
# **References:**
#
# [📘 Savov, I. (2016). *No Bullshit Guide to Linear Algebra*, Section 7.2](https://minireference.com/)
#
# ---
#
# [⬅️ Previous: Special Types of Matrices](./01_special_types_of_matrices.ipynb) | [Next: Symmetric Matrices ➡️](./03_symmetric_matrices.ipynb)
